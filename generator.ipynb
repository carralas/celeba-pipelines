# %%
import pandas as pd
import numpy as np

# %%
celeba = pd.read_csv('celeba-dataset/list_attr_celeba.csv')

# %%
attractive = celeba[celeba['Attractive'] == 1]

# %%
attractive.sample(5)
# Out:
#           image_id  5_o_Clock_Shadow  Arched_Eyebrows  Attractive  \
# 22133   022134.jpg                 1               -1           1
# 70275   070276.jpg                -1               -1           1
# 133928  133929.jpg                -1               -1           1
# 54244   054245.jpg                -1                1           1
# 118452  118453.jpg                -1               -1           1
#
#         Bags_Under_Eyes  Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  ...  \
# 22133                -1    -1     -1        -1        -1          -1  ...
# 70275                -1    -1      1        -1        -1          -1  ...
# 133928               -1    -1     -1         1        -1          -1  ...
# 54244                -1    -1      1         1         1           1  ...
# 118452                1    -1      1        -1         1          -1  ...
#
#         Sideburns  Smiling  Straight_Hair  Wavy_Hair  Wearing_Earrings  \
# ...

# %%
noattractive = celeba[celeba['Attractive'] == -1]

# %%
noattractive.sample(5)
# Out:
#           image_id  5_o_Clock_Shadow  Arched_Eyebrows  Attractive  \
# 104924  104925.jpg                -1               -1          -1
# 198741  198742.jpg                -1               -1          -1
# 160821  160822.jpg                -1               -1          -1
# 150241  150242.jpg                -1               -1          -1
# 198226  198227.jpg                -1               -1          -1
#
#         Bags_Under_Eyes  Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  ...  \
# 104924                1    -1     -1        -1        -1          -1  ...
# 198741               -1    -1     -1        -1        -1          -1  ...
# 160821               -1    -1     -1         1         1           1  ...
# 150241               -1    -1     -1        -1        -1           1  ...
# 198226                1    -1     -1        -1        -1          -1  ...
#
#         Sideburns  Smiling  Straight_Hair  Wavy_Hair  Wearing_Earrings  \
# ...

# %%
male = celeba[celeba['Male'] == 1]

# %%
male.sample(3)
# Out:
#           image_id  5_o_Clock_Shadow  Arched_Eyebrows  Attractive  \
# 172920  172921.jpg                 1               -1           1
# 30817   030818.jpg                -1               -1          -1
# 72437   072438.jpg                -1               -1           1
#
#         Bags_Under_Eyes  Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  ...  \
# 172920                1    -1     -1        -1         1           1  ...
# 30817                -1    -1     -1        -1         1          -1  ...
# 72437                -1    -1      1        -1         1           1  ...
#
#         Sideburns  Smiling  Straight_Hair  Wavy_Hair  Wearing_Earrings  \
# 172920         -1       -1             -1         -1                -1
# 30817          -1        1             -1         -1                -1
# 72437          -1       -1             -1         -1                -1
#
#         Wearing_Hat  Wearing_Lipstick  Wearing_Necklace  Wearing_Necktie  \
# ...

# %%
nomale = celeba[celeba['Male'] == -1]

# %%
nomale.sample(3)
# Out:
#          image_id  5_o_Clock_Shadow  Arched_Eyebrows  Attractive  \
# 9834   009835.jpg                -1                1           1
# 19385  019386.jpg                -1               -1          -1
# 30305  030306.jpg                -1               -1           1
#
#        Bags_Under_Eyes  Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  ...  \
# 9834                -1    -1     -1        -1         1           1  ...
# 19385               -1    -1     -1        -1        -1          -1  ...
# 30305               -1    -1     -1        -1        -1          -1  ...
#
#        Sideburns  Smiling  Straight_Hair  Wavy_Hair  Wearing_Earrings  \
# 9834          -1        1             -1          1                -1
# 19385         -1       -1             -1          1                -1
# 30305         -1       -1             -1          1                 1
#
#        Wearing_Hat  Wearing_Lipstick  Wearing_Necklace  Wearing_Necktie  Young
# ...

# %%
young = celeba[celeba['Young'] == 1]

# %%
young.sample(3)
# Out:
#          image_id  5_o_Clock_Shadow  Arched_Eyebrows  Attractive  \
# 8737   008738.jpg                -1               -1           1
# 56519  056520.jpg                -1               -1          -1
# 28230  028231.jpg                -1               -1           1
#
#        Bags_Under_Eyes  Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  ...  \
# 8737                -1    -1     -1        -1        -1          -1  ...
# 56519               -1    -1     -1        -1         1          -1  ...
# 28230               -1    -1      1        -1        -1           1  ...
#
#        Sideburns  Smiling  Straight_Hair  Wavy_Hair  Wearing_Earrings  \
# 8737          -1       -1              1         -1                -1
# 56519         -1       -1             -1          1                -1
# 28230         -1       -1             -1         -1                -1
#
#        Wearing_Hat  Wearing_Lipstick  Wearing_Necklace  Wearing_Necktie  Young
# ...

# %%
noyoung = celeba[celeba['Young'] == -1]

# %%
noyoung.sample(3)
# Out:
#           image_id  5_o_Clock_Shadow  Arched_Eyebrows  Attractive  \
# 136633  136634.jpg                -1               -1          -1
# 26782   026783.jpg                -1               -1          -1
# 89644   089645.jpg                -1               -1          -1
#
#         Bags_Under_Eyes  Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  ...  \
# 136633                1    -1     -1        -1        -1          -1  ...
# 26782                -1    -1     -1        -1        -1           1  ...
# 89644                -1    -1     -1         1        -1          -1  ...
#
#         Sideburns  Smiling  Straight_Hair  Wavy_Hair  Wearing_Earrings  \
# 136633         -1        1             -1          1                -1
# 26782          -1       -1              1         -1                -1
# 89644          -1        1             -1          1                 1
#
#         Wearing_Hat  Wearing_Lipstick  Wearing_Necklace  Wearing_Necktie  \
# ...

# %%
veryatt = pd.read_csv('celeba-corr-above-375-all.csv')

# %%
veryatt.sample(5)
# Out:
#        image_id  5_o_Clock_Shadow  Arched_Eyebrows  Attractive  \
# 30943    194866                -1                1           1
# 22104    137992                -1                1           1
# 12651     79112                -1                1           1
# 3276      20692                -1                1           1
# 18930    118282                -1                1           1
#
#        Bags_Under_Eyes  Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  ...  \
# 30943               -1    -1     -1         1        -1           1  ...
# 22104               -1    -1      1         1        -1          -1  ...
# 12651               -1    -1     -1         1        -1          -1  ...
# 3276                -1    -1     -1         1        -1          -1  ...
# 18930               -1    -1     -1        -1        -1          -1  ...
#
#        Sideburns  Smiling  Straight_Hair  Wavy_Hair  Wearing_Earrings  \
# 30943         -1        1             -1          1                -1
# ...

# %%
verynoatt = pd.read_csv('celeba-corr-above-375-none.csv')

# %%
verynoatt.sample(5)
# Out:
#         image_id  5_o_Clock_Shadow  Arched_Eyebrows  Attractive  \
# 49474      58747                -1               -1          -1
# 41545      49343                 1               -1           1
# 41405      49177                -1               -1          -1
# 165673    196968                -1               -1           1
# 51588      61288                 1               -1           1
#
#         Bags_Under_Eyes  Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  ...  \
# 49474                -1    -1     -1         1        -1           1  ...
# 41545                 1    -1     -1        -1        -1          -1  ...
# 41405                 1    -1     -1        -1        -1          -1  ...
# 165673               -1    -1     -1        -1        -1          -1  ...
# 51588                -1    -1     -1        -1        -1          -1  ...
#
#         Sideburns  Smiling  Straight_Hair  Wavy_Hair  Wearing_Earrings  \
# ...

# %%
someatt = pd.read_csv('celeba-corr-above-25-all.csv')

# %%
someatt.sample(5)
# Out:
#        image_id  5_o_Clock_Shadow  Arched_Eyebrows  Attractive  \
# 26159     74824                -1                1           1
# 66335    190177                -1                1           1
# 33025     94237                -1               -1           1
# 14529     41521                -1               -1           1
# 38518    110129                -1               -1           1
#
#        Bags_Under_Eyes  Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  ...  \
# 26159                1    -1     -1        -1        -1          -1  ...
# 66335               -1    -1     -1        -1        -1           1  ...
# 33025               -1    -1     -1        -1        -1          -1  ...
# 14529               -1    -1     -1        -1        -1           1  ...
# 38518                1    -1     -1         1         1          -1  ...
#
#        Sideburns  Smiling  Straight_Hair  Wavy_Hair  Wearing_Earrings  \
# 26159         -1        1              1         -1                -1
# ...

# %%
somenoatt = pd.read_csv('celeba-corr-above-25-none.csv')

# %%
somenoatt.sample(5)
# Out:
#         image_id  5_o_Clock_Shadow  Arched_Eyebrows  Attractive  \
# 102349    157205                -1                1          -1
# 61196      94213                -1               -1          -1
# 109699    168480                 1               -1          -1
# 49367      75932                -1               -1          -1
# 10196      15713                 1               -1           1
#
#         Bags_Under_Eyes  Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  ...  \
# 102349               -1    -1     -1        -1         1           1  ...
# 61196                -1    -1     -1        -1        -1           1  ...
# 109699               -1    -1     -1        -1        -1          -1  ...
# 49367                -1    -1     -1        -1         1          -1  ...
# 10196                -1    -1     -1         1         1           1  ...
#
#         Sideburns  Smiling  Straight_Hair  Wavy_Hair  Wearing_Earrings  \
# ...
